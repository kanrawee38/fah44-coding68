# %% [markdown]
# <a href="https://colab.research.google.com/github/kanrawee38/fah44-coding68/blob/main/untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import datetime
import time

name = input("ตั้งชื่อการปลุก: ")
alarm_time =
# Out:
# ตั้งชื่อการปลุก: 9njowxFi'giupo
# เวลาที่ต้องการให้ปลุก (HH:MM): 06.00
# รูปแบบเวลาไม่ถูกต้อง กรุณาใช้ HH:MM
# เวลาที่ต้องการให้ปลุก (HH:MM): 06.00
# รูปแบบเวลาไม่ถูกต้อง กรุณาใช้ HH:MM
# เวลาที่ต้องการให้ปลุก (HH:MM): 06.00
# รูปแบบเวลาไม่ถูกต้อง กรุณาใช้ HH:MM
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipython-input-2163321911.py", line 8, in <cell line: 0>
#     alarm_time = input("เวลาที่ต้องการให้ปลุก (HH:MM): ")
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py", line 1177, in raw_input
#     return self._input_request(
#            ^^^^^^^^^^^^^^^^^^^^
# ...

# %%
alarm = input("ใส่เวลาที่ต้องการให้ปลุก (HH:MM): ")
while True:
    now = datetime.datetime.now().strftime("%H:%M")
    if now == alarm:
        print(" ถึงเวลาแจ้งเตือนแล้ว")
        break
    time.sleep(60)
# Out:
# ใส่เวลาที่ต้องการให้ปลุก (HH:MM): 06.00
