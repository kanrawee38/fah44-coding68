# %% [markdown]
# <a href="https://colab.research.google.com/github/kanrawee38/fah44-coding68/blob/main/finai38_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# """
# เลือกโจทย์: โปรแกรมคำนวร เลขคู่ เลขคี่
# I: รับค่าตัวเลขจำนวนเต็ม
# P:นำตัวเลขไปหาร 2 แล้วตรวจสอบเศษจากการหาร
# ถ้าเศษ เท่ากับ 0 เป็นเลขคู่
# ถ้าเศษ ไม่เท่ากับ 0 เป้นเลขคี่
# O:แสดงผลว่าเป้นเลขคู่หรือเลขคี่
# ตัวแปร: num
# """

# %%
print("โปรแกรมตรวจสอบเลขคู่ เลขคี่")
print("พัฒนาโดย Kanrawee")
num = int(input('กรอกตัวเลขจำนวนเต็ม'))
if num % 2 == 0:
    print ("เป็นเลขคู่ค่า")
else:
    print("เป็นเลขคี่ค่า")
print("ขอบคุณที่ใช้บริการค่ะ")
# Out:
# โปรแกรมตรวจสอบเลขคู่ เลขคี่
# พัฒนาโดย Kanrawee
# กรอกตัวเลขจำนวนเต็ม52
# เป็นเลขคู่ค่า
# ขอบคุณที่ใช้บริการค่ะ
